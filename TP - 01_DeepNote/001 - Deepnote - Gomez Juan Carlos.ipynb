# %% [markdown]
# # TP01 \- Deepnote Gomez Juan Carlos

# %% [markdown]
# Soy estudiante de la carrera de Ciencia de Datos e Inteligencia Artificial y me interesa especialmente el desarrollo de aplicaciones y sistemas\. Actualmente trabajo en el área de IT y busco seguir incorporando conocimientos relacionados con la tecnología y la programación\. De esta materia espero aprender cómo se desarrollan sistemas que incorporan Inteligencia Artificial y poder aplicar esos conocimientos en proyectos laborales y personales\.

# %%
nombre = "Juan"
materia = "Desarrollo de Sistemas de Inteligencia Artificial"

print(f"Mi nombre es {nombre} y estoy cursando la materia {materia}")
# Out:
# Mi nombre es Juan y estoy cursando la materia Desarrollo de Sistemas de Inteligencia Artificial

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ce4b4a07-1e3c-4cba-b01a-425f3feb7540' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
